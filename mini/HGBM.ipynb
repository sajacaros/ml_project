# %% [markdown]
# loss: "binary_crossentropy" (이진 분류) or "categorical_crossentropy"
#
# learning_rate: 0 ~ 1
#
# max_iter: 부스팅 반복 횟수
#
# max_leaf_nodes: 최대 리프 노드 수 지정
#
# max_depth: 트리의 최대 깊이를 제한
#
# min_samples_leaf: 리프 노드의 최소 샘플 수
#
# l2_regularization: L2 정규화 항 추가
#
# max_bins: 히스토그램의 최대 구간 수 지정
#
# early_stopping: 조기 중지를 활성화, 개선이 멈추면 학습을 중지
#
# validation_fraction: 검증 데이터 세트에 할당된 비율을 지정
#
# n_iter_no_change: 조기 중지를 활성화, 지정된 반복 횟수 동안 모델 성능 비개선 시 학습중지
#
# random_state: 61
#
# verbose: 학습 과정 중에 출력되는 정보의 양 제어
#
# warm_start: True: 이전 모델을 재사용한 추가 훈련 수행
#
# categorical_features: 범주형 변수로 처리할 특성의 인덱스를 지정
#
# monotonic_cst: 특성과 예측 클래스 간의 증가 또는 감소 제약을 지정

# %% [markdown]
# HGBM 공식
# https://scikit-learn.org/stable/modules/generated/sklearn.ensemble.HistGradientBoostingRegressor.html
#
# Light GBM VS HistGradientBoostingmachine
#
# 1. 동작 방식의 차이: 트리 분할방법(리프중심 VS 히스토그램 중심)
# 2. 속도 및 메모리 사용 우수 정도: LGBM < HGBM
# 3. 트리 확장방법: 수직적(n_estimators 사용) / 수평적(n_estimators 사용 x)
#
# 공통 파라미터:
#
# num_leaves
# max_depth
# learning_rate
# feature_fraction: 각 트리 분할에서 고려할 피처의 비율
#
# HGBM 특유의 파라미터:
#
# max_iter: 최대 반복 횟수, 트리를 확장하며 예측 오차를 줄이는 데 사용
# l2_regularization: L2 정규화의 강도, 높을수록 정규화 ↑
# max_bins: 데이터를 히스토그램으로 분할하는 데 사용.
# categorical_features: 범주형 변수의 목록을 지정

# %%
pip install optuna
# Out:
# Collecting optuna
#   Downloading optuna-3.3.0-py3-none-any.whl (404 kB)
#                                               0.0/404.2 kB ? eta -:--:--
#      --                                    30.7/404.2 kB 660.6 kB/s eta 0:00:01
#      -------------------------------------  399.4/404.2 kB 4.2 MB/s eta 0:00:01
#      -------------------------------------- 404.2/404.2 kB 4.2 MB/s eta 0:00:00
# Collecting alembic>=1.5.0 (from optuna)
#   Downloading alembic-1.12.0-py3-none-any.whl (226 kB)
#                                               0.0/226.0 kB ? eta -:--:--
#      ------------------------------------- 226.0/226.0 kB 13.5 MB/s eta 0:00:00
# Collecting cmaes>=0.10.0 (from optuna)
#   Downloading cmaes-0.10.0-py3-none-any.whl (29 kB)
# Collecting colorlog (from optuna)
#   Downloading colorlog-6.7.0-py2.py3-none-any.whl (11 kB)
# Requirement already satisfied: numpy in c:\users\user\anaconda3\lib\site-packages (from optuna) (1.24.3)
# Requirement already satisfied: packaging>=20.0 in c:\users\user\appdata\roaming\python\python311\site-packages (from optuna) (23.1)
# Requirement already satisfied: sqlalchemy>=1.3.0 in c:\users\user\anaconda3\lib\site-packages (from optuna) (1.4.39)
# Requirement already satisfied: tqdm in c:\users\user\anaconda3\lib\site-packages (from optuna) (4.65.0)
# Requirement already satisfied: PyYAML in c:\users\user\anaconda3\lib\site-packages (from optuna) (6.0)
# Collecting Mako (from alembic>=1.5.0->optuna)
#   Downloading Mako-1.2.4-py3-none-any.whl (78 kB)
#                                               0.0/78.7 kB ? eta -:--:--
#      ---------------------------------------- 78.7/78.7 kB 4.6 MB/s eta 0:00:00
# Requirement already satisfied: typing-extensions>=4 in c:\users\user\anaconda3\lib\site-packages (from alembic>=1.5.0->optuna) (4.6.3)
# Requirement already satisfied: greenlet!=0.4.17 in c:\users\user\anaconda3\lib\site-packages (from sqlalchemy>=1.3.0->optuna) (2.0.1)
# Requirement already satisfied: colorama in c:\users\user\appdata\roaming\python\python311\site-packages (from colorlog->optuna) (0.4.6)
# Requirement already satisfied: MarkupSafe>=0.9.2 in c:\users\user\anaconda3\lib\site-packages (from Mako->alembic>=1.5.0->optuna) (2.1.1)
# Installing collected packages: Mako, colorlog, cmaes, alembic, optuna
# Successfully installed Mako-1.2.4 alembic-1.12.0 cmaes-0.10.0 colorlog-6.7.0 optuna-3.3.0
# Note: you may need to restart the kernel to use updated packages.

# %%
import optuna
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from sklearn.experimental import enable_hist_gradient_boosting
#HGBM
from sklearn.ensemble import HistGradientBoostingClassifier

# %%
#데이터 생성
train = pd.read_csv('./play/train.csv', index_col = 'id')
test = pd.read_csv('./play/test.csv', index_col = 'id')
submission_df = pd.read_csv('./play/sample_submission.csv', index_col='id')

# %%
X = train.drop(columns = ['defects'])
y = train.defects.astype(int)

# %%
# 데이터 분할
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=61)

# HistGradientBoostingClassifier 모델
model = HistGradientBoostingClassifier()

# 모델 훈련
model.fit(X_train, y_train)

# 테스트 데이터로 예측
y_pred = model.predict(X_test)

# 데이터로 모델 평가
cm = confusion_matrix(y_test, y_pred)
f1 = f1_score(y_test, y_pred, average='weighted')  # F1 점수 계산

#print("confusion Matrix", cm)
# Out:
# C:\Users\user\anaconda3\Lib\site-packages\sklearn\utils\validation.py:767: FutureWarning:
#
# is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#
# C:\Users\user\anaconda3\Lib\site-packages\sklearn\utils\validation.py:605: FutureWarning:
#
# is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#
# C:\Users\user\anaconda3\Lib\site-packages\sklearn\utils\validation.py:614: FutureWarning:
#
# is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#
# C:\Users\user\anaconda3\Lib\site-packages\sklearn\utils\validation.py:605: FutureWarning:
#
# is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#
# C:\Users\user\anaconda3\Lib\site-packages\sklearn\utils\validation.py:614: FutureWarning:
#
# is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#
# C:\Users\user\anaconda3\Lib\site-packages\sklearn\utils\validation.py:767: FutureWarning:
#
# is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#
# C:\Users\user\anaconda3\Lib\site-packages\sklearn\utils\validation.py:605: FutureWarning:
#
# is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#
# C:\Users\user\anaconda3\Lib\site-packages\sklearn\utils\validation.py:614: FutureWarning:
#
# is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#
# C:\Users\user\anaconda3\Lib\site-packages\sklearn\utils\validation.py:605: FutureWarning:
#
# is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#
# C:\Users\user\anaconda3\Lib\site-packages\sklearn\utils\validation.py:614: FutureWarning:
#
# is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#
# C:\Users\user\anaconda3\Lib\site-packages\sklearn\utils\validation.py:605: FutureWarning:
#
# is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#
# C:\Users\user\anaconda3\Lib\site-packages\sklearn\utils\validation.py:614: FutureWarning:
#
# is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#
# C:\Users\user\anaconda3\Lib\site-packages\sklearn\utils\validation.py:605: FutureWarning:
#
# is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#
# C:\Users\user\anaconda3\Lib\site-packages\sklearn\utils\validation.py:614: FutureWarning:
#
# is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#
# C:\Users\user\anaconda3\Lib\site-packages\sklearn\utils\validation.py:605: FutureWarning:
#
# is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#
# C:\Users\user\anaconda3\Lib\site-packages\sklearn\utils\validation.py:614: FutureWarning:
#
# is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#
# C:\Users\user\anaconda3\Lib\site-packages\sklearn\utils\validation.py:605: FutureWarning:
#
# is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#
# C:\Users\user\anaconda3\Lib\site-packages\sklearn\utils\validation.py:614: FutureWarning:
#
# is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#
# C:\Users\user\anaconda3\Lib\site-packages\sklearn\utils\validation.py:605: FutureWarning:
#
# is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#
# C:\Users\user\anaconda3\Lib\site-packages\sklearn\utils\validation.py:614: FutureWarning:
#
# is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#
# C:\Users\user\anaconda3\Lib\site-packages\sklearn\utils\validation.py:605: FutureWarning:
#
# is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#
# C:\Users\user\anaconda3\Lib\site-packages\sklearn\utils\validation.py:614: FutureWarning:
#
# is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#
# C:\Users\user\anaconda3\Lib\site-packages\sklearn\utils\validation.py:605: FutureWarning:
#
# is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#
# C:\Users\user\anaconda3\Lib\site-packages\sklearn\utils\validation.py:614: FutureWarning:
#
# is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#
# C:\Users\user\anaconda3\Lib\site-packages\sklearn\utils\validation.py:605: FutureWarning:
#
# is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#
# C:\Users\user\anaconda3\Lib\site-packages\sklearn\utils\validation.py:614: FutureWarning:
#
# is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.

# %%
# F1 점수 출력
print("Weighted F1 Score:", f1)
# 정확도 평가
accuracy = accuracy_score(y_test, y_pred)
print("정확도:", accuracy)
# Out:
# Weighted F1 Score: 0.7917350374576028
# 정확도: 0.8111826266398074
# C:\Users\user\anaconda3\Lib\site-packages\sklearn\utils\validation.py:605: FutureWarning:
#
# is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#
# C:\Users\user\anaconda3\Lib\site-packages\sklearn\utils\validation.py:614: FutureWarning:
#
# is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#
# C:\Users\user\anaconda3\Lib\site-packages\sklearn\utils\validation.py:605: FutureWarning:
#
# is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#
# C:\Users\user\anaconda3\Lib\site-packages\sklearn\utils\validation.py:614: FutureWarning:
#
# is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#
# C:\Users\user\anaconda3\Lib\site-packages\sklearn\utils\validation.py:605: FutureWarning:
#
# is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#
# C:\Users\user\anaconda3\Lib\site-packages\sklearn\utils\validation.py:614: FutureWarning:
#
# is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.

# %%
# HistGradientBoostingClassifier + optuna
def optimizer(trial):
    loss = "binary_crossentropy" #분류방법
    max_iter = trial.suggest_int("max_iter", 100, 1000)
    learning_rate = trial.suggest_float('learning_rate', 0.01, 0.1)
    max_depth = trial.suggest_int('max_depth', 10, 100)
    l2_regularization = trial.suggest_float('l2_regularization', 1e-5, 1e-3)
    model = HistGradientBoostingClassifier(loss = loss, learning_rate = learning_rate,
                                           max_depth = max_depth, l2_regularization = l2_regularization
                                           ,random_state=61)
    model.fit(X_train, y_train)
    y_pred = model.predict(X_test)
    
    accuracy = accuracy_score(y_test, y_pred)
    return accuracy

import optuna
study = optuna.create_study(direction = 'maximize')
study.optimize(optimizer, n_trials=50)
print("Best Accuracy: %.4f" % study.best_value)
print("Best params: ", study.best_trial.params)
# Out:
# [I 2023-10-11 15:34:23,973] A new study created in memory with name: no-name-b4f78ca5-0e15-44c3-9274-0641ecac42ec
# C:\Users\user\anaconda3\Lib\site-packages\sklearn\utils\validation.py:767: FutureWarning:
#
# is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#
# C:\Users\user\anaconda3\Lib\site-packages\sklearn\utils\validation.py:605: FutureWarning:
#
# is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#
# C:\Users\user\anaconda3\Lib\site-packages\sklearn\utils\validation.py:614: FutureWarning:
#
# is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#
# C:\Users\user\anaconda3\Lib\site-packages\sklearn\utils\validation.py:605: FutureWarning:
#
# is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#
# C:\Users\user\anaconda3\Lib\site-packages\sklearn\utils\validation.py:614: FutureWarning:
#
# is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#
# C:\Users\user\anaconda3\Lib\site-packages\sklearn\ensemble\_hist_gradient_boosting\gradient_boosting.py:1998: FutureWarning:
#
# The loss 'binary_crossentropy' was deprecated in v1.1 and will be removed in version 1.3. Use 'log_loss' which is equivalent.
#
# C:\Users\user\anaconda3\Lib\site-packages\sklearn\utils\validation.py:767: FutureWarning:
#
# is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#
# C:\Users\user\anaconda3\Lib\site-packages\sklearn\utils\validation.py:605: FutureWarning:
#
# is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#
# C:\Users\user\anaconda3\Lib\site-packages\sklearn\utils\validation.py:614: FutureWarning:
#
# is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#
# C:\Users\user\anaconda3\Lib\site-packages\sklearn\utils\validation.py:605: FutureWarning:
#
# is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#
# C:\Users\user\anaconda3\Lib\site-packages\sklearn\utils\validation.py:614: FutureWarning:
#
# is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#
# C:\Users\user\anaconda3\Lib\site-packages\sklearn\utils\validation.py:605: FutureWarning:
#
# is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#
# C:\Users\user\anaconda3\Lib\site-packages\sklearn\utils\validation.py:614: FutureWarning:
#
# is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#
# C:\Users\user\anaconda3\Lib\site-packages\sklearn\utils\validation.py:605: FutureWarning:
#
# is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#
# C:\Users\user\anaconda3\Lib\site-packages\sklearn\utils\validation.py:614: FutureWarning:
#
# is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#
# [I 2023-10-11 15:34:24,446] Trial 0 finished with value: 0.8112808922517565 and parameters: {'max_iter': 584, 'learning_rate': 0.09968271677081127, 'max_depth': 68, 'l2_regularization': 0.0007276833911772118}. Best is trial 0 with value: 0.8112808922517565.
# C:\Users\user\anaconda3\Lib\site-packages\sklearn\utils\validation.py:767: FutureWarning:
#
# is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#
# C:\Users\user\anaconda3\Lib\site-packages\sklearn\utils\validation.py:605: FutureWarning:
#
# is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#
# C:\Users\user\anaconda3\Lib\site-packages\sklearn\utils\validation.py:614: FutureWarning:
#
# is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#
# C:\Users\user\anaconda3\Lib\site-packages\sklearn\utils\validation.py:605: FutureWarning:
#
# is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#
# C:\Users\user\anaconda3\Lib\site-packages\sklearn\utils\validation.py:614: FutureWarning:
#
# is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#
# C:\Users\user\anaconda3\Lib\site-packages\sklearn\ensemble\_hist_gradient_boosting\gradient_boosting.py:1998: FutureWarning:
#
# The loss 'binary_crossentropy' was deprecated in v1.1 and will be removed in version 1.3. Use 'log_loss' which is equivalent.
#
# C:\Users\user\anaconda3\Lib\site-packages\sklearn\utils\validation.py:767: FutureWarning:
#
# is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#
# C:\Users\user\anaconda3\Lib\site-packages\sklearn\utils\validation.py:605: FutureWarning:
#
# is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#
# C:\Users\user\anaconda3\Lib\site-packages\sklearn\utils\validation.py:614: FutureWarning:
#
# is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#
# C:\Users\user\anaconda3\Lib\site-packages\sklearn\utils\validation.py:605: FutureWarning:
#
# is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#
# C:\Users\user\anaconda3\Lib\site-packages\sklearn\utils\validation.py:614: FutureWarning:
#
# is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#
# C:\Users\user\anaconda3\Lib\site-packages\sklearn\utils\validation.py:605: FutureWarning:
#
# is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#
# C:\Users\user\anaconda3\Lib\site-packages\sklearn\utils\validation.py:614: FutureWarning:
#
# is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#
# C:\Users\user\anaconda3\Lib\site-packages\sklearn\utils\validation.py:605: FutureWarning:
#
# is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#
# C:\Users\user\anaconda3\Lib\site-packages\sklearn\utils\validation.py:614: FutureWarning:
#
# is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#
# [I 2023-10-11 15:34:25,033] Trial 1 finished with value: 0.8118213531174765 and parameters: {'max_iter': 352, 'learning_rate': 0.08973598524372385, 'max_depth': 24, 'l2_regularization': 0.0006922029795283495}. Best is trial 1 with value: 0.8118213531174765.
# C:\Users\user\anaconda3\Lib\site-packages\sklearn\utils\validation.py:767: FutureWarning:
#
# is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#
# C:\Users\user\anaconda3\Lib\site-packages\sklearn\utils\validation.py:605: FutureWarning:
#
# is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#
# C:\Users\user\anaconda3\Lib\site-packages\sklearn\utils\validation.py:614: FutureWarning:
#
# is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#
# C:\Users\user\anaconda3\Lib\site-packages\sklearn\utils\validation.py:605: FutureWarning:
#
# is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#
# C:\Users\user\anaconda3\Lib\site-packages\sklearn\utils\validation.py:614: FutureWarning:
#
# is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#
# C:\Users\user\anaconda3\Lib\site-packages\sklearn\ensemble\_hist_gradient_boosting\gradient_boosting.py:1998: FutureWarning:
#
# The loss 'binary_crossentropy' was deprecated in v1.1 and will be removed in version 1.3. Use 'log_loss' which is equivalent.
# C:\Users\user\anaconda3\Lib\site-packages\sklearn\utils\validation.py:767: FutureWarning:
#
# is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#
# C:\Users\user\anaconda3\Lib\site-packages\sklearn\utils\validation.py:605: FutureWarning:
#
# is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#
# C:\Users\user\anaconda3\Lib\site-packages\sklearn\utils\validation.py:614: FutureWarning:
#
# is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#
# C:\Users\user\anaconda3\Lib\site-packages\sklearn\utils\validation.py:605: FutureWarning:
#
# is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#
# C:\Users\user\anaconda3\Lib\site-packages\sklearn\utils\validation.py:614: FutureWarning:
#
# is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#
# C:\Users\user\anaconda3\Lib\site-packages\sklearn\utils\validation.py:605: FutureWarning:
#
# is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#
# C:\Users\user\anaconda3\Lib\site-packages\sklearn\utils\validation.py:614: FutureWarning:
#
# is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#
# C:\Users\user\anaconda3\Lib\site-packages\sklearn\utils\validation.py:605: FutureWarning:
#
# is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#
# C:\Users\user\anaconda3\Lib\site-packages\sklearn\utils\validation.py:614: FutureWarning:
#
# is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#
# [I 2023-10-11 15:34:25,895] Trial 2 finished with value: 0.811231759445782 and parameters: {'max_iter': 379, 'learning_rate': 0.04439574575572294, 'max_depth': 18, 'l2_regularization': 0.0008743687913897389}. Best is trial 1 with value: 0.8118213531174765.
# C:\Users\user\anaconda3\Lib\site-packages\sklearn\utils\validation.py:767: FutureWarning:
#
# is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#
# C:\Users\user\anaconda3\Lib\site-packages\sklearn\utils\validation.py:605: FutureWarning:
#
# is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#
# C:\Users\user\anaconda3\Lib\site-packages\sklearn\utils\validation.py:614: FutureWarning:
#
# is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#
# C:\Users\user\anaconda3\Lib\site-packages\sklearn\utils\validation.py:605: FutureWarning:
#
# is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#
# C:\Users\user\anaconda3\Lib\site-packages\sklearn\utils\validation.py:614: FutureWarning:
#
# is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#
# C:\Users\user\anaconda3\Lib\site-packages\sklearn\ensemble\_hist_gradient_boosting\gradient_boosting.py:1998: FutureWarning:
#
# The loss 'binary_crossentropy' was deprecated in v1.1 and will be removed in version 1.3. Use 'log_loss' which is equivalent.
#
# C:\Users\user\anaconda3\Lib\site-packages\sklearn\utils\validation.py:767: FutureWarning:
#
# is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#
# C:\Users\user\anaconda3\Lib\site-packages\sklearn\utils\validation.py:605: FutureWarning:
#
# is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#
# C:\Users\user\anaconda3\Lib\site-packages\sklearn\utils\validation.py:614: FutureWarning:
#
# is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#
# C:\Users\user\anaconda3\Lib\site-packages\sklearn\utils\validation.py:605: FutureWarning:
#
# is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#
# C:\Users\user\anaconda3\Lib\site-packages\sklearn\utils\validation.py:614: FutureWarning:
#
# is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#
# C:\Users\user\anaconda3\Lib\site-packages\sklearn\utils\validation.py:605: FutureWarning:
#
# is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#
# C:\Users\user\anaconda3\Lib\site-packages\sklearn\utils\validation.py:614: FutureWarning:
#
# is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#
# C:\Users\user\anaconda3\Lib\site-packages\sklearn\utils\validation.py:605: FutureWarning:
#
# is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#
# C:\Users\user\anaconda3\Lib\site-packages\sklearn\utils\validation.py:614: FutureWarning:
#
# is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#
# [I 2023-10-11 15:34:26,687] Trial 3 finished with value: 0.811330025057731 and parameters: {'max_iter': 231, 'learning_rate': 0.04057673996796696, 'max_depth': 28, 'l2_regularization': 0.00042089638271589796}. Best is trial 1 with value: 0.8118213531174765.
# C:\Users\user\anaconda3\Lib\site-packages\sklearn\utils\validation.py:767: FutureWarning:
#
# is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#
# C:\Users\user\anaconda3\Lib\site-packages\sklearn\utils\validation.py:605: FutureWarning:
#
# is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#
# C:\Users\user\anaconda3\Lib\site-packages\sklearn\utils\validation.py:614: FutureWarning:
#
# is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#
# C:\Users\user\anaconda3\Lib\site-packages\sklearn\utils\validation.py:605: FutureWarning:
#
# is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#
# C:\Users\user\anaconda3\Lib\site-packages\sklearn\utils\validation.py:614: FutureWarning:
#
# is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#
# C:\Users\user\anaconda3\Lib\site-packages\sklearn\ensemble\_hist_gradient_boosting\gradient_boosting.py:1998: FutureWarning:
#
# The loss 'binary_crossentropy' was deprecated in v1.1 and will be removed in version 1.3. Use 'log_loss' which is equivalent.
#
# C:\Users\user\anaconda3\Lib\site-packages\sklearn\utils\validation.py:767: FutureWarning:
#
# is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#
# C:\Users\user\anaconda3\Lib\site-packages\sklearn\utils\validation.py:605: FutureWarning:
#
# is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#
# C:\Users\user\anaconda3\Lib\site-packages\sklearn\utils\validation.py:614: FutureWarning:
#
# is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#
# C:\Users\user\anaconda3\Lib\site-packages\sklearn\utils\validation.py:605: FutureWarning:
#
# is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#
# C:\Users\user\anaconda3\Lib\site-packages\sklearn\utils\validation.py:614: FutureWarning:
#
# is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#
# C:\Users\user\anaconda3\Lib\site-packages\sklearn\utils\validation.py:605: FutureWarning:
#
# is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#
# C:\Users\user\anaconda3\Lib\site-packages\sklearn\utils\validation.py:614: FutureWarning:
#
# is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#
# C:\Users\user\anaconda3\Lib\site-packages\sklearn\utils\validation.py:605: FutureWarning:
#
# is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#
# C:\Users\user\anaconda3\Lib\site-packages\sklearn\utils\validation.py:614: FutureWarning:
#
# is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#
# [I 2023-10-11 15:34:27,471] Trial 4 finished with value: 0.811330025057731 and parameters: {'max_iter': 662, 'learning_rate': 0.037572830545943375, 'max_depth': 25, 'l2_regularization': 0.0004586023817433192}. Best is trial 1 with value: 0.8118213531174765.
# C:\Users\user\anaconda3\Lib\site-packages\sklearn\utils\validation.py:767: FutureWarning:
#
# is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#
# C:\Users\user\anaconda3\Lib\site-packages\sklearn\utils\validation.py:605: FutureWarning:
#
# is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#
# C:\Users\user\anaconda3\Lib\site-packages\sklearn\utils\validation.py:614: FutureWarning:
#
# is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#
# C:\Users\user\anaconda3\Lib\site-packages\sklearn\utils\validation.py:605: FutureWarning:
#
# is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#
# C:\Users\user\anaconda3\Lib\site-packages\sklearn\utils\validation.py:614: FutureWarning:
#
# is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#
# C:\Users\user\anaconda3\Lib\site-packages\sklearn\ensemble\_hist_gradient_boosting\gradient_boosting.py:1998: FutureWarning:
#
# The loss 'binary_crossentropy' was deprecated in v1.1 and will be removed in version 1.3. Use 'log_loss' which is equivalent.
#
# C:\Users\user\anaconda3\Lib\site-packages\sklearn\utils\validation.py:767: FutureWarning:
#
# is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#
# C:\Users\user\anaconda3\Lib\site-packages\sklearn\utils\validation.py:605: FutureWarning:
#
# is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#
# C:\Users\user\anaconda3\Lib\site-packages\sklearn\utils\validation.py:614: FutureWarning:
#
# is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#
# C:\Users\user\anaconda3\Lib\site-packages\sklearn\utils\validation.py:605: FutureWarning:
#
# is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#
# C:\Users\user\anaconda3\Lib\site-packages\sklearn\utils\validation.py:614: FutureWarning:
#
# is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#
# C:\Users\user\anaconda3\Lib\site-packages\sklearn\utils\validation.py:605: FutureWarning:
#
# is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#
# C:\Users\user\anaconda3\Lib\site-packages\sklearn\utils\validation.py:614: FutureWarning:
#
# is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#
# C:\Users\user\anaconda3\Lib\site-packages\sklearn\utils\validation.py:605: FutureWarning:
#
# is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#
# C:\Users\user\anaconda3\Lib\site-packages\sklearn\utils\validation.py:614: FutureWarning:
#
# is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#
# [I 2023-10-11 15:34:28,106] Trial 5 finished with value: 0.8112808922517565 and parameters: {'max_iter': 877, 'learning_rate': 0.0776192891446201, 'max_depth': 26, 'l2_regularization': 0.0007415552251012366}. Best is trial 1 with value: 0.8118213531174765.
# C:\Users\user\anaconda3\Lib\site-packages\sklearn\utils\validation.py:767: FutureWarning:
#
# is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#
# C:\Users\user\anaconda3\Lib\site-packages\sklearn\utils\validation.py:605: FutureWarning:
#
# is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#
# C:\Users\user\anaconda3\Lib\site-packages\sklearn\utils\validation.py:614: FutureWarning:
#
# is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#
# C:\Users\user\anaconda3\Lib\site-packages\sklearn\utils\validation.py:605: FutureWarning:
#
# is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#
# C:\Users\user\anaconda3\Lib\site-packages\sklearn\utils\validation.py:614: FutureWarning:
#
# is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#
# C:\Users\user\anaconda3\Lib\site-packages\sklearn\ensemble\_hist_gradient_boosting\gradient_boosting.py:1998: FutureWarning:
#
# The loss 'binary_crossentropy' was deprecated in v1.1 and will be removed in version 1.3. Use 'log_loss' which is equivalent.
#
# C:\Users\user\anaconda3\Lib\site-packages\sklearn\utils\validation.py:767: FutureWarning:
#
# is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#
# C:\Users\user\anaconda3\Lib\site-packages\sklearn\utils\validation.py:605: FutureWarning:
#
# is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#
# C:\Users\user\anaconda3\Lib\site-packages\sklearn\utils\validation.py:614: FutureWarning:
#
# is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#
# C:\Users\user\anaconda3\Lib\site-packages\sklearn\utils\validation.py:605: FutureWarning:
#
# is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#
# C:\Users\user\anaconda3\Lib\site-packages\sklearn\utils\validation.py:614: FutureWarning:
#
# is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#
# C:\Users\user\anaconda3\Lib\site-packages\sklearn\utils\validation.py:605: FutureWarning:
#
# is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#
# C:\Users\user\anaconda3\Lib\site-packages\sklearn\utils\validation.py:614: FutureWarning:
#
# is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#
# C:\Users\user\anaconda3\Lib\site-packages\sklearn\utils\validation.py:605: FutureWarning:
#
# is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#
# C:\Users\user\anaconda3\Lib\site-packages\sklearn\utils\validation.py:614: FutureWarning:
#
# is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#
# [I 2023-10-11 15:34:28,901] Trial 6 finished with value: 0.8107404313860365 and parameters: {'max_iter': 427, 'learning_rate': 0.021672945591299418, 'max_depth': 75, 'l2_regularization': 0.0007035656650743391}. Best is trial 1 with value: 0.8118213531174765.
# C:\Users\user\anaconda3\Lib\site-packages\sklearn\utils\validation.py:767: FutureWarning:
#
# is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#
# C:\Users\user\anaconda3\Lib\site-packages\sklearn\utils\validation.py:605: FutureWarning:
#
# is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#
# C:\Users\user\anaconda3\Lib\site-packages\sklearn\utils\validation.py:614: FutureWarning:
#
# is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#
# C:\Users\user\anaconda3\Lib\site-packages\sklearn\utils\validation.py:605: FutureWarning:
#
# is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#
# C:\Users\user\anaconda3\Lib\site-packages\sklearn\utils\validation.py:614: FutureWarning:
#
# is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#
# C:\Users\user\anaconda3\Lib\site-packages\sklearn\ensemble\_hist_gradient_boosting\gradient_boosting.py:1998: FutureWarning:
#
# The loss 'binary_crossentropy' was deprecated in v1.1 and will be removed in version 1.3. Use 'log_loss' which is equivalent.
#
# C:\Users\user\anaconda3\Lib\site-packages\sklearn\utils\validation.py:767: FutureWarning:
#
# is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#
# C:\Users\user\anaconda3\Lib\site-packages\sklearn\utils\validation.py:605: FutureWarning:
#
# is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#
# C:\Users\user\anaconda3\Lib\site-packages\sklearn\utils\validation.py:614: FutureWarning:
#
# is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#
# C:\Users\user\anaconda3\Lib\site-packages\sklearn\utils\validation.py:605: FutureWarning:
#
# is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#
# C:\Users\user\anaconda3\Lib\site-packages\sklearn\utils\validation.py:614: FutureWarning:
#
# is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#
# C:\Users\user\anaconda3\Lib\site-packages\sklearn\utils\validation.py:605: FutureWarning:
#
# is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#
# C:\Users\user\anaconda3\Lib\site-packages\sklearn\utils\validation.py:614: FutureWarning:
#
# is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#
# C:\Users\user\anaconda3\Lib\site-packages\sklearn\utils\validation.py:605: FutureWarning:
#
# is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#
# C:\Users\user\anaconda3\Lib\site-packages\sklearn\utils\validation.py:614: FutureWarning:
#
# is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#
# [I 2023-10-11 15:34:29,705] Trial 7 finished with value: 0.8007173389672284 and parameters: {'max_iter': 410, 'learning_rate': 0.010244352624050868, 'max_depth': 86, 'l2_regularization': 0.0006631467463689466}. Best is trial 1 with value: 0.8118213531174765.
# C:\Users\user\anaconda3\Lib\site-packages\sklearn\utils\validation.py:767: FutureWarning:
#
# is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#
# C:\Users\user\anaconda3\Lib\site-packages\sklearn\utils\validation.py:605: FutureWarning:
#
# is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#
# C:\Users\user\anaconda3\Lib\site-packages\sklearn\utils\validation.py:614: FutureWarning:
#
# is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#
# C:\Users\user\anaconda3\Lib\site-packages\sklearn\utils\validation.py:605: FutureWarning:
#
# is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#
# C:\Users\user\anaconda3\Lib\site-packages\sklearn\utils\validation.py:614: FutureWarning:
#
# is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#
# C:\Users\user\anaconda3\Lib\site-packages\sklearn\ensemble\_hist_gradient_boosting\gradient_boosting.py:1998: FutureWarning:
#
# The loss 'binary_crossentropy' was deprecated in v1.1 and will be removed in version 1.3. Use 'log_loss' which is equivalent.
#
# C:\Users\user\anaconda3\Lib\site-packages\sklearn\utils\validation.py:767: FutureWarning:
#
# is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#
# C:\Users\user\anaconda3\Lib\site-packages\sklearn\utils\validation.py:605: FutureWarning:
#
# is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#
# C:\Users\user\anaconda3\Lib\site-packages\sklearn\utils\validation.py:614: FutureWarning:
#
# is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#
# C:\Users\user\anaconda3\Lib\site-packages\sklearn\utils\validation.py:605: FutureWarning:
#
# is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#
# C:\Users\user\anaconda3\Lib\site-packages\sklearn\utils\validation.py:614: FutureWarning:
#
# is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#
# C:\Users\user\anaconda3\Lib\site-packages\sklearn\utils\validation.py:605: FutureWarning:
#
# is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#
# C:\Users\user\anaconda3\Lib\site-packages\sklearn\utils\validation.py:614: FutureWarning:
#
# is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#
# C:\Users\user\anaconda3\Lib\site-packages\sklearn\utils\validation.py:605: FutureWarning:
#
# is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#
# C:\Users\user\anaconda3\Lib\site-packages\sklearn\utils\validation.py:614: FutureWarning:
#
# is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#
# [I 2023-10-11 15:34:30,535] Trial 8 finished with value: 0.8114774234756547 and parameters: {'max_iter': 850, 'learning_rate': 0.03936121645838159, 'max_depth': 63, 'l2_regularization': 7.752099281469842e-05}. Best is trial 1 with value: 0.8118213531174765.
# C:\Users\user\anaconda3\Lib\site-packages\sklearn\utils\validation.py:767: FutureWarning:
#
# is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#
# C:\Users\user\anaconda3\Lib\site-packages\sklearn\utils\validation.py:605: FutureWarning:
#
# is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#
# C:\Users\user\anaconda3\Lib\site-packages\sklearn\utils\validation.py:614: FutureWarning:
#
# is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#
# C:\Users\user\anaconda3\Lib\site-packages\sklearn\utils\validation.py:605: FutureWarning:
#
# is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#
# C:\Users\user\anaconda3\Lib\site-packages\sklearn\utils\validation.py:614: FutureWarning:
#
# is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#
# C:\Users\user\anaconda3\Lib\site-packages\sklearn\ensemble\_hist_gradient_boosting\gradient_boosting.py:1998: FutureWarning:
#
# The loss 'binary_crossentropy' was deprecated in v1.1 and will be removed in version 1.3. Use 'log_loss' which is equivalent.
#
# C:\Users\user\anaconda3\Lib\site-packages\sklearn\utils\validation.py:767: FutureWarning:
#
# is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#
# C:\Users\user\anaconda3\Lib\site-packages\sklearn\utils\validation.py:605: FutureWarning:
#
# is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#
# C:\Users\user\anaconda3\Lib\site-packages\sklearn\utils\validation.py:614: FutureWarning:
#
# is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#
# C:\Users\user\anaconda3\Lib\site-packages\sklearn\utils\validation.py:605: FutureWarning:
#
# is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#
# C:\Users\user\anaconda3\Lib\site-packages\sklearn\utils\validation.py:614: FutureWarning:
#
# is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#
# C:\Users\user\anaconda3\Lib\site-packages\sklearn\utils\validation.py:605: FutureWarning:
#
# is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#
# C:\Users\user\anaconda3\Lib\site-packages\sklearn\utils\validation.py:614: FutureWarning:
#
# is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#
# C:\Users\user\anaconda3\Lib\site-packages\sklearn\utils\validation.py:605: FutureWarning:
#
# is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#
# C:\Users\user\anaconda3\Lib\site-packages\sklearn\utils\validation.py:614: FutureWarning:
#
# is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#
# [I 2023-10-11 15:34:31,307] Trial 9 finished with value: 0.8109369626099346 and parameters: {'max_iter': 207, 'learning_rate': 0.06620859517662549, 'max_depth': 19, 'l2_regularization': 5.689269564983527e-05}. Best is trial 1 with value: 0.8118213531174765.
# C:\Users\user\anaconda3\Lib\site-packages\sklearn\utils\validation.py:767: FutureWarning:
#
# is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#
# C:\Users\user\anaconda3\Lib\site-packages\sklearn\utils\validation.py:605: FutureWarning:
#
# is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#
# C:\Users\user\anaconda3\Lib\site-packages\sklearn\utils\validation.py:614: FutureWarning:
#
# is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#
# C:\Users\user\anaconda3\Lib\site-packages\sklearn\utils\validation.py:605: FutureWarning:
#
# is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#
# C:\Users\user\anaconda3\Lib\site-packages\sklearn\utils\validation.py:614: FutureWarning:
#
# is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#
# C:\Users\user\anaconda3\Lib\site-packages\sklearn\ensemble\_hist_gradient_boosting\gradient_boosting.py:1998: FutureWarning:
#
# The loss 'binary_crossentropy' was deprecated in v1.1 and will be removed in version 1.3. Use 'log_loss' which is equivalent.
#
# C:\Users\user\anaconda3\Lib\site-packages\sklearn\utils\validation.py:767: FutureWarning:
#
# is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#
# C:\Users\user\anaconda3\Lib\site-packages\sklearn\utils\validation.py:605: FutureWarning:
#
# is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#
# C:\Users\user\anaconda3\Lib\site-packages\sklearn\utils\validation.py:614: FutureWarning:
#
# is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#
# C:\Users\user\anaconda3\Lib\site-packages\sklearn\utils\validation.py:605: FutureWarning:
#
# is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#
# C:\Users\user\anaconda3\Lib\site-packages\sklearn\utils\validation.py:614: FutureWarning:
#
# is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#
# C:\Users\user\anaconda3\Lib\site-packages\sklearn\utils\validation.py:605: FutureWarning:
#
# is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#
# C:\Users\user\anaconda3\Lib\site-packages\sklearn\utils\validation.py:614: FutureWarning:
#
# is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#
# C:\Users\user\anaconda3\Lib\site-packages\sklearn\utils\validation.py:605: FutureWarning:
#
# is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#
# C:\Users\user\anaconda3\Lib\site-packages\sklearn\utils\validation.py:614: FutureWarning:
#
# is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#
# [I 2023-10-11 15:34:31,967] Trial 10 finished with value: 0.811330025057731 and parameters: {'max_iter': 101, 'learning_rate': 0.09861399229329712, 'max_depth': 45, 'l2_regularization': 0.0009819586863120161}. Best is trial 1 with value: 0.8118213531174765.
# C:\Users\user\anaconda3\Lib\site-packages\sklearn\utils\validation.py:767: FutureWarning:
#
# is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#
# C:\Users\user\anaconda3\Lib\site-packages\sklearn\utils\validation.py:605: FutureWarning:
#
# is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#
# C:\Users\user\anaconda3\Lib\site-packages\sklearn\utils\validation.py:614: FutureWarning:
#
# is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#
# C:\Users\user\anaconda3\Lib\site-packages\sklearn\utils\validation.py:605: FutureWarning:
#
# is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#
# C:\Users\user\anaconda3\Lib\site-packages\sklearn\utils\validation.py:614: FutureWarning:
#
# is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#
# C:\Users\user\anaconda3\Lib\site-packages\sklearn\ensemble\_hist_gradient_boosting\gradient_boosting.py:1998: FutureWarning:
#
# The loss 'binary_crossentropy' was deprecated in v1.1 and will be removed in version 1.3. Use 'log_loss' which is equivalent.
#
# C:\Users\user\anaconda3\Lib\site-packages\sklearn\utils\validation.py:767: FutureWarning:
#
# is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#
# C:\Users\user\anaconda3\Lib\site-packages\sklearn\utils\validation.py:605: FutureWarning:
#
# is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#
# C:\Users\user\anaconda3\Lib\site-packages\sklearn\utils\validation.py:614: FutureWarning:
#
# is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#
# C:\Users\user\anaconda3\Lib\site-packages\sklearn\utils\validation.py:605: FutureWarning:
#
# is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#
# C:\Users\user\anaconda3\Lib\site-packages\sklearn\utils\validation.py:614: FutureWarning:
#
# is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#
# C:\Users\user\anaconda3\Lib\site-packages\sklearn\utils\validation.py:605: FutureWarning:
#
# is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#
# C:\Users\user\anaconda3\Lib\site-packages\sklearn\utils\validation.py:614: FutureWarning:
#
# is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#
# C:\Users\user\anaconda3\Lib\site-packages\sklearn\utils\validation.py:605: FutureWarning:
#
# is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#
# C:\Users\user\anaconda3\Lib\site-packages\sklearn\utils\validation.py:614: FutureWarning:
#
# is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#
# [I 2023-10-11 15:34:32,721] Trial 11 finished with value: 0.8111334938338328 and parameters: {'max_iter': 912, 'learning_rate': 0.060409448028243815, 'max_depth': 51, 'l2_regularization': 1.4513862571151985e-05}. Best is trial 1 with value: 0.8118213531174765.
# C:\Users\user\anaconda3\Lib\site-packages\sklearn\utils\validation.py:767: FutureWarning:
#
# is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#
# C:\Users\user\anaconda3\Lib\site-packages\sklearn\utils\validation.py:605: FutureWarning:
#
# is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#
# C:\Users\user\anaconda3\Lib\site-packages\sklearn\utils\validation.py:614: FutureWarning:
#
# is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#
# C:\Users\user\anaconda3\Lib\site-packages\sklearn\utils\validation.py:605: FutureWarning:
#
# is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#
# C:\Users\user\anaconda3\Lib\site-packages\sklearn\utils\validation.py:614: FutureWarning:
#
# is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#
# C:\Users\user\anaconda3\Lib\site-packages\sklearn\ensemble\_hist_gradient_boosting\gradient_boosting.py:1998: FutureWarning:
#
# The loss 'binary_crossentropy' was deprecated in v1.1 and will be removed in version 1.3. Use 'log_loss' which is equivalent.
#
# C:\Users\user\anaconda3\Lib\site-packages\sklearn\utils\validation.py:767: FutureWarning:
#
# is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#
# C:\Users\user\anaconda3\Lib\site-packages\sklearn\utils\validation.py:605: FutureWarning:
#
# is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#
# C:\Users\user\anaconda3\Lib\site-packages\sklearn\utils\validation.py:614: FutureWarning:
#
# is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#
# C:\Users\user\anaconda3\Lib\site-packages\sklearn\utils\validation.py:605: FutureWarning:
#
# is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#
# C:\Users\user\anaconda3\Lib\site-packages\sklearn\utils\validation.py:614: FutureWarning:
#
# is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#
# C:\Users\user\anaconda3\Lib\site-packages\sklearn\utils\validation.py:605: FutureWarning:
#
# is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#
# C:\Users\user\anaconda3\Lib\site-packages\sklearn\utils\validation.py:614: FutureWarning:
#
# is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#
# C:\Users\user\anaconda3\Lib\site-packages\sklearn\utils\validation.py:605: FutureWarning:
#
# is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#
# C:\Users\user\anaconda3\Lib\site-packages\sklearn\utils\validation.py:614: FutureWarning:
#
# is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#
# [I 2023-10-11 15:34:33,337] Trial 12 finished with value: 0.8111334938338328 and parameters: {'max_iter': 750, 'learning_rate': 0.08202172777179532, 'max_depth': 99, 'l2_regularization': 0.0002473949944212496}. Best is trial 1 with value: 0.8118213531174765.
# C:\Users\user\anaconda3\Lib\site-packages\sklearn\utils\validation.py:767: FutureWarning:
#
# is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#
# C:\Users\user\anaconda3\Lib\site-packages\sklearn\utils\validation.py:605: FutureWarning:
#
# is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#
# C:\Users\user\anaconda3\Lib\site-packages\sklearn\utils\validation.py:614: FutureWarning:
#
# is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#
# C:\Users\user\anaconda3\Lib\site-packages\sklearn\utils\validation.py:605: FutureWarning:
#
# is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#
# C:\Users\user\anaconda3\Lib\site-packages\sklearn\utils\validation.py:614: FutureWarning:
#
# is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#
# C:\Users\user\anaconda3\Lib\site-packages\sklearn\ensemble\_hist_gradient_boosting\gradient_boosting.py:1998: FutureWarning:
#
# The loss 'binary_crossentropy' was deprecated in v1.1 and will be removed in version 1.3. Use 'log_loss' which is equivalent.
#
# C:\Users\user\anaconda3\Lib\site-packages\sklearn\utils\validation.py:767: FutureWarning:
#
# is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#
# C:\Users\user\anaconda3\Lib\site-packages\sklearn\utils\validation.py:605: FutureWarning:
#
# is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#
# C:\Users\user\anaconda3\Lib\site-packages\sklearn\utils\validation.py:614: FutureWarning:
#
# is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#
# C:\Users\user\anaconda3\Lib\site-packages\sklearn\utils\validation.py:605: FutureWarning:
#
# is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#
# C:\Users\user\anaconda3\Lib\site-packages\sklearn\utils\validation.py:614: FutureWarning:
#
# is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#
# C:\Users\user\anaconda3\Lib\site-packages\sklearn\utils\validation.py:605: FutureWarning:
#
# is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#
# C:\Users\user\anaconda3\Lib\site-packages\sklearn\utils\validation.py:614: FutureWarning:
#
# is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#
# C:\Users\user\anaconda3\Lib\site-packages\sklearn\utils\validation.py:605: FutureWarning:
#
# is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#
# C:\Users\user\anaconda3\Lib\site-packages\sklearn\utils\validation.py:614: FutureWarning:
#
# is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#
# ...
#
# C:\Users\user\anaconda3\Lib\site-packages\sklearn\utils\validation.py:767: FutureWarning:
#
# is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#
# C:\Users\user\anaconda3\Lib\site-packages\sklearn\utils\validation.py:605: FutureWarning:
#
# is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#
# C:\Users\user\anaconda3\Lib\site-packages\sklearn\utils\validation.py:614: FutureWarning:
#
# is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#
# C:\Users\user\anaconda3\Lib\site-packages\sklearn\utils\validation.py:605: FutureWarning:
#
# is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#
# C:\Users\user\anaconda3\Lib\site-packages\sklearn\utils\validation.py:614: FutureWarning:
#
# is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#
# C:\Users\user\anaconda3\Lib\site-packages\sklearn\utils\validation.py:605: FutureWarning:
#
# is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#
# C:\Users\user\anaconda3\Lib\site-packages\sklearn\utils\validation.py:614: FutureWarning:
#
# is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#
# C:\Users\user\anaconda3\Lib\site-packages\sklearn\utils\validation.py:605: FutureWarning:
#
# is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#
# C:\Users\user\anaconda3\Lib\site-packages\sklearn\utils\validation.py:614: FutureWarning:
#
# is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#
# [I 2023-10-11 15:34:54,058] Trial 45 finished with value: 0.8115265562816293 and parameters: {'max_iter': 467, 'learning_rate': 0.09075916111050181, 'max_depth': 28, 'l2_regularization': 0.000688612383576078}. Best is trial 36 with value: 0.8121161499533238.
# C:\Users\user\anaconda3\Lib\site-packages\sklearn\utils\validation.py:767: FutureWarning:
#
# is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#
# C:\Users\user\anaconda3\Lib\site-packages\sklearn\utils\validation.py:605: FutureWarning:
#
# is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#
# C:\Users\user\anaconda3\Lib\site-packages\sklearn\utils\validation.py:614: FutureWarning:
#
# is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#
# C:\Users\user\anaconda3\Lib\site-packages\sklearn\utils\validation.py:605: FutureWarning:
#
# is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#
# C:\Users\user\anaconda3\Lib\site-packages\sklearn\utils\validation.py:614: FutureWarning:
#
# is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#
# C:\Users\user\anaconda3\Lib\site-packages\sklearn\ensemble\_hist_gradient_boosting\gradient_boosting.py:1998: FutureWarning:
#
# The loss 'binary_crossentropy' was deprecated in v1.1 and will be removed in version 1.3. Use 'log_loss' which is equivalent.
#
# C:\Users\user\anaconda3\Lib\site-packages\sklearn\utils\validation.py:767: FutureWarning:
#
# is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#
# C:\Users\user\anaconda3\Lib\site-packages\sklearn\utils\validation.py:605: FutureWarning:
#
# is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#
# C:\Users\user\anaconda3\Lib\site-packages\sklearn\utils\validation.py:614: FutureWarning:
#
# is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#
# C:\Users\user\anaconda3\Lib\site-packages\sklearn\utils\validation.py:605: FutureWarning:
#
# is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#
# C:\Users\user\anaconda3\Lib\site-packages\sklearn\utils\validation.py:614: FutureWarning:
#
# is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#
# C:\Users\user\anaconda3\Lib\site-packages\sklearn\utils\validation.py:605: FutureWarning:
#
# is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#
# C:\Users\user\anaconda3\Lib\site-packages\sklearn\utils\validation.py:614: FutureWarning:
#
# is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#
# C:\Users\user\anaconda3\Lib\site-packages\sklearn\utils\validation.py:605: FutureWarning:
#
# is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#
# C:\Users\user\anaconda3\Lib\site-packages\sklearn\utils\validation.py:614: FutureWarning:
#
# is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#
# [I 2023-10-11 15:34:54,696] Trial 46 finished with value: 0.8107404313860365 and parameters: {'max_iter': 166, 'learning_rate': 0.07317902498916383, 'max_depth': 42, 'l2_regularization': 0.00047438558309046997}. Best is trial 36 with value: 0.8121161499533238.
# C:\Users\user\anaconda3\Lib\site-packages\sklearn\utils\validation.py:767: FutureWarning:
#
# is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#
# C:\Users\user\anaconda3\Lib\site-packages\sklearn\utils\validation.py:605: FutureWarning:
#
# is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#
# C:\Users\user\anaconda3\Lib\site-packages\sklearn\utils\validation.py:614: FutureWarning:
#
# is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#
# C:\Users\user\anaconda3\Lib\site-packages\sklearn\utils\validation.py:605: FutureWarning:
#
# is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#
# C:\Users\user\anaconda3\Lib\site-packages\sklearn\utils\validation.py:614: FutureWarning:
#
# is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#
# C:\Users\user\anaconda3\Lib\site-packages\sklearn\ensemble\_hist_gradient_boosting\gradient_boosting.py:1998: FutureWarning:
#
# The loss 'binary_crossentropy' was deprecated in v1.1 and will be removed in version 1.3. Use 'log_loss' which is equivalent.
#
# C:\Users\user\anaconda3\Lib\site-packages\sklearn\utils\validation.py:767: FutureWarning:
#
# is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#
# C:\Users\user\anaconda3\Lib\site-packages\sklearn\utils\validation.py:605: FutureWarning:
#
# is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#
# C:\Users\user\anaconda3\Lib\site-packages\sklearn\utils\validation.py:614: FutureWarning:
#
# is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#
# C:\Users\user\anaconda3\Lib\site-packages\sklearn\utils\validation.py:605: FutureWarning:
#
# is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#
# C:\Users\user\anaconda3\Lib\site-packages\sklearn\utils\validation.py:614: FutureWarning:
#
# is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#
# C:\Users\user\anaconda3\Lib\site-packages\sklearn\utils\validation.py:605: FutureWarning:
#
# is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#
# C:\Users\user\anaconda3\Lib\site-packages\sklearn\utils\validation.py:614: FutureWarning:
#
# is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#
# C:\Users\user\anaconda3\Lib\site-packages\sklearn\utils\validation.py:605: FutureWarning:
#
# is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#
# C:\Users\user\anaconda3\Lib\site-packages\sklearn\utils\validation.py:614: FutureWarning:
#
# is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#
# [I 2023-10-11 15:34:55,196] Trial 47 finished with value: 0.811673954699553 and parameters: {'max_iter': 585, 'learning_rate': 0.09595676112505179, 'max_depth': 54, 'l2_regularization': 0.0007616688871880248}. Best is trial 36 with value: 0.8121161499533238.
# C:\Users\user\anaconda3\Lib\site-packages\sklearn\utils\validation.py:767: FutureWarning:
#
# is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#
# C:\Users\user\anaconda3\Lib\site-packages\sklearn\utils\validation.py:605: FutureWarning:
#
# is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#
# C:\Users\user\anaconda3\Lib\site-packages\sklearn\utils\validation.py:614: FutureWarning:
#
# is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#
# C:\Users\user\anaconda3\Lib\site-packages\sklearn\utils\validation.py:605: FutureWarning:
#
# is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#
# C:\Users\user\anaconda3\Lib\site-packages\sklearn\utils\validation.py:614: FutureWarning:
#
# is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#
# C:\Users\user\anaconda3\Lib\site-packages\sklearn\ensemble\_hist_gradient_boosting\gradient_boosting.py:1998: FutureWarning:
#
# The loss 'binary_crossentropy' was deprecated in v1.1 and will be removed in version 1.3. Use 'log_loss' which is equivalent.
#
# C:\Users\user\anaconda3\Lib\site-packages\sklearn\utils\validation.py:767: FutureWarning:
#
# is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#
# C:\Users\user\anaconda3\Lib\site-packages\sklearn\utils\validation.py:605: FutureWarning:
#
# is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#
# C:\Users\user\anaconda3\Lib\site-packages\sklearn\utils\validation.py:614: FutureWarning:
#
# is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#
# C:\Users\user\anaconda3\Lib\site-packages\sklearn\utils\validation.py:605: FutureWarning:
#
# is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#
# C:\Users\user\anaconda3\Lib\site-packages\sklearn\utils\validation.py:614: FutureWarning:
#
# is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#
# C:\Users\user\anaconda3\Lib\site-packages\sklearn\utils\validation.py:605: FutureWarning:
#
# is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#
# C:\Users\user\anaconda3\Lib\site-packages\sklearn\utils\validation.py:614: FutureWarning:
#
# is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#
# C:\Users\user\anaconda3\Lib\site-packages\sklearn\utils\validation.py:605: FutureWarning:
#
# is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#
# C:\Users\user\anaconda3\Lib\site-packages\sklearn\utils\validation.py:614: FutureWarning:
#
# is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#
# [I 2023-10-11 15:34:55,864] Trial 48 finished with value: 0.8111334938338328 and parameters: {'max_iter': 515, 'learning_rate': 0.06278612748646989, 'max_depth': 87, 'l2_regularization': 0.0006359899130851522}. Best is trial 36 with value: 0.8121161499533238.
# C:\Users\user\anaconda3\Lib\site-packages\sklearn\utils\validation.py:767: FutureWarning:
#
# is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#
# C:\Users\user\anaconda3\Lib\site-packages\sklearn\utils\validation.py:605: FutureWarning:
#
# is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#
# C:\Users\user\anaconda3\Lib\site-packages\sklearn\utils\validation.py:614: FutureWarning:
#
# is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#
# C:\Users\user\anaconda3\Lib\site-packages\sklearn\utils\validation.py:605: FutureWarning:
#
# is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#
# C:\Users\user\anaconda3\Lib\site-packages\sklearn\utils\validation.py:614: FutureWarning:
#
# is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#
# C:\Users\user\anaconda3\Lib\site-packages\sklearn\ensemble\_hist_gradient_boosting\gradient_boosting.py:1998: FutureWarning:
#
# The loss 'binary_crossentropy' was deprecated in v1.1 and will be removed in version 1.3. Use 'log_loss' which is equivalent.
#
# C:\Users\user\anaconda3\Lib\site-packages\sklearn\utils\validation.py:767: FutureWarning:
#
# is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#
# C:\Users\user\anaconda3\Lib\site-packages\sklearn\utils\validation.py:605: FutureWarning:
#
# is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#
# C:\Users\user\anaconda3\Lib\site-packages\sklearn\utils\validation.py:614: FutureWarning:
#
# is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#
# C:\Users\user\anaconda3\Lib\site-packages\sklearn\utils\validation.py:605: FutureWarning:
#
# is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#
# C:\Users\user\anaconda3\Lib\site-packages\sklearn\utils\validation.py:614: FutureWarning:
#
# is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#
# C:\Users\user\anaconda3\Lib\site-packages\sklearn\utils\validation.py:605: FutureWarning:
#
# is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#
# C:\Users\user\anaconda3\Lib\site-packages\sklearn\utils\validation.py:614: FutureWarning:
#
# is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#
# C:\Users\user\anaconda3\Lib\site-packages\sklearn\utils\validation.py:605: FutureWarning:
#
# is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#
# C:\Users\user\anaconda3\Lib\site-packages\sklearn\utils\validation.py:614: FutureWarning:
#
# is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#
# [I 2023-10-11 15:34:56,632] Trial 49 finished with value: 0.811330025057731 and parameters: {'max_iter': 403, 'learning_rate': 0.05808843625479831, 'max_depth': 37, 'l2_regularization': 0.0005312079628439448}. Best is trial 36 with value: 0.8121161499533238.
# Best Accuracy: 0.8121
# Best params:  {'max_iter': 567, 'learning_rate': 0.06829862122784122, 'max_depth': 48, 'l2_regularization': 0.00048183914198247387}

# %%
study.trials_dataframe()
# Out:
#     number     value             datetime_start          datetime_complete  \
# 0        0  0.811281 2023-10-11 15:34:23.974918 2023-10-11 15:34:24.446529
# 1        1  0.811821 2023-10-11 15:34:24.447529 2023-10-11 15:34:25.033661
# 2        2  0.811232 2023-10-11 15:34:25.034661 2023-10-11 15:34:25.895855
# 3        3  0.811330 2023-10-11 15:34:25.896855 2023-10-11 15:34:26.687538
# 4        4  0.811330 2023-10-11 15:34:26.688538 2023-10-11 15:34:27.471720
# 5        5  0.811281 2023-10-11 15:34:27.472720 2023-10-11 15:34:28.105367
# 6        6  0.810740 2023-10-11 15:34:28.106367 2023-10-11 15:34:28.901553
# 7        7  0.800717 2023-10-11 15:34:28.902553 2023-10-11 15:34:29.705733
# 8        8  0.811477 2023-10-11 15:34:29.706734 2023-10-11 15:34:30.535425
# 9        9  0.810937 2023-10-11 15:34:30.536426 2023-10-11 15:34:31.307598
# 10      10  0.811330 2023-10-11 15:34:31.308598 2023-10-11 15:34:31.967747
# 11      11  0.811133 2023-10-11 15:34:31.968747 2023-10-11 15:34:32.721916
# 12      12  0.811133 2023-10-11 15:34:32.722917 2023-10-11 15:34:33.337055
# 13      13  0.811379 2023-10-11 15:34:33.337055 2023-10-11 15:34:34.162240
# 14      14  0.811281 2023-10-11 15:34:34.163240 2023-10-11 15:34:34.904407
# 15      15  0.810888 2023-10-11 15:34:34.905408 2023-10-11 15:34:35.697100
# 16      16  0.810642 2023-10-11 15:34:35.698101 2023-10-11 15:34:36.503785
# 17      17  0.811969 2023-10-11 15:34:36.504785 2023-10-11 15:34:37.154932
# 18      18  0.810839 2023-10-11 15:34:37.155932 2023-10-11 15:34:37.709056
# 19      19  0.811576 2023-10-11 15:34:37.710056 2023-10-11 15:34:38.325195
# 20      20  0.810740 2023-10-11 15:34:38.325195 2023-10-11 15:34:38.986344
# 21      21  0.810888 2023-10-11 15:34:38.987344 2023-10-11 15:34:39.529466
# 22      22  0.810790 2023-10-11 15:34:39.530466 2023-10-11 15:34:40.071588
# 23      23  0.811084 2023-10-11 15:34:40.072588 2023-10-11 15:34:40.595706
# 24      24  0.810839 2023-10-11 15:34:40.596706 2023-10-11 15:34:41.185839
# 25      25  0.810839 2023-10-11 15:34:41.186839 2023-10-11 15:34:41.772970
# 26      26  0.811870 2023-10-11 15:34:41.773971 2023-10-11 15:34:42.338098
# 27      27  0.810691 2023-10-11 15:34:42.339098 2023-10-11 15:34:42.895223
# 28      28  0.810544 2023-10-11 15:34:42.895223 2023-10-11 15:34:43.554371
# 29      29  0.811379 2023-10-11 15:34:43.555372 2023-10-11 15:34:44.075992
# 30      30  0.811920 2023-10-11 15:34:44.076992 2023-10-11 15:34:44.798657
# 31      31  0.811379 2023-10-11 15:34:44.799658 2023-10-11 15:34:45.317774
# 32      32  0.810642 2023-10-11 15:34:45.318775 2023-10-11 15:34:45.934913
# 33      33  0.811428 2023-10-11 15:34:45.934913 2023-10-11 15:34:46.577057
# 34      34  0.811428 2023-10-11 15:34:46.578058 2023-10-11 15:34:47.125181
# 35      35  0.811379 2023-10-11 15:34:47.126181 2023-10-11 15:34:47.700310
# 36      36  0.812116 2023-10-11 15:34:47.701311 2023-10-11 15:34:48.349456
# 37      37  0.811281 2023-10-11 15:34:48.350457 2023-10-11 15:34:48.969596
# 38      38  0.811428 2023-10-11 15:34:48.970596 2023-10-11 15:34:49.706762
# 39      39  0.811133 2023-10-11 15:34:49.707762 2023-10-11 15:34:50.349409
# 40      40  0.811477 2023-10-11 15:34:50.350409 2023-10-11 15:34:50.961546
# 41      41  0.810937 2023-10-11 15:34:50.962546 2023-10-11 15:34:51.619720
# 42      42  0.810986 2023-10-11 15:34:51.620721 2023-10-11 15:34:52.155347
# 43      43  0.811232 2023-10-11 15:34:52.155347 2023-10-11 15:34:52.773486
# 44      44  0.811723 2023-10-11 15:34:52.774487 2023-10-11 15:34:53.471146
# 45      45  0.811527 2023-10-11 15:34:53.472146 2023-10-11 15:34:54.058278
# 46      46  0.810740 2023-10-11 15:34:54.058278 2023-10-11 15:34:54.695421
# 47      47  0.811674 2023-10-11 15:34:54.696422 2023-10-11 15:34:55.195534
# 48      48  0.811133 2023-10-11 15:34:55.196534 2023-10-11 15:34:55.864684
# 49      49  0.811330 2023-10-11 15:34:55.864684 2023-10-11 15:34:56.632863
#
#                  duration  params_l2_regularization  params_learning_rate  \
# 0  0 days 00:00:00.471611                  0.000728              0.099683
# 1  0 days 00:00:00.586132                  0.000692              0.089736
# 2  0 days 00:00:00.861194                  0.000874              0.044396
# 3  0 days 00:00:00.790683                  0.000421              0.040577
# 4  0 days 00:00:00.783182                  0.000459              0.037573
# 5  0 days 00:00:00.632647                  0.000742              0.077619
# 6  0 days 00:00:00.795186                  0.000704              0.021673
# 7  0 days 00:00:00.803180                  0.000663              0.010244
# 8  0 days 00:00:00.828691                  0.000078              0.039361
# 9  0 days 00:00:00.771172                  0.000057              0.066209
# 10 0 days 00:00:00.659149                  0.000982              0.098614
# 11 0 days 00:00:00.753169                  0.000015              0.060409
# 12 0 days 00:00:00.614138                  0.000247              0.082022
# 13 0 days 00:00:00.825185                  0.000301              0.053081
# 14 0 days 00:00:00.741167                  0.000570              0.070578
# 15 0 days 00:00:00.791692                  0.000155              0.051489
# 16 0 days 00:00:00.805684                  0.000362              0.030762
# 17 0 days 00:00:00.650147                  0.000539              0.087069
# 18 0 days 00:00:00.553124                  0.000544              0.087868
# 19 0 days 00:00:00.615139                  0.000617              0.090278
# 20 0 days 00:00:00.661149                  0.000498              0.074274
# 21 0 days 00:00:00.542122                  0.000586              0.089491
# 22 0 days 00:00:00.541122                  0.000616              0.087313
# 23 0 days 00:00:00.523118                  0.000798              0.092762
# 24 0 days 00:00:00.589133                  0.000625              0.079913
# 25 0 days 00:00:00.586131                  0.000531              0.082641
# 26 0 days 00:00:00.564127                  0.000480              0.094966
# 27 0 days 00:00:00.556125                  0.000465              0.095601
# 28 0 days 00:00:00.659148                  0.000407              0.099200
# 29 0 days 00:00:00.520620                  0.000529              0.094710
# 30 0 days 00:00:00.721665                  0.000691              0.072946
# 31 0 days 00:00:00.518116                  0.000689              0.084232
# 32 0 days 00:00:00.616138                  0.000772              0.086599
# 33 0 days 00:00:00.642144                  0.000651              0.075792
# 34 0 days 00:00:00.547123                  0.000844              0.092799
# 35 0 days 00:00:00.574129                  0.000715              0.079371
# 36 0 days 00:00:00.648145                  0.000482              0.068299
# 37 0 days 00:00:00.619139                  0.000479              0.069830
# 38 0 days 00:00:00.736166                  0.000424              0.063035
# 39 0 days 00:00:00.641647                  0.000582              0.073583
# 40 0 days 00:00:00.611137                  0.000510              0.077678
# 41 0 days 00:00:00.657174                  0.000667              0.085423
# 42 0 days 00:00:00.534626                  0.000726              0.099787
# 43 0 days 00:00:00.618139                  0.000577              0.081672
# 44 0 days 00:00:00.696659                  0.000431              0.068501
# 45 0 days 00:00:00.586132                  0.000689              0.090759
# 46 0 days 00:00:00.637143                  0.000474              0.073179
# 47 0 days 00:00:00.499112                  0.000762              0.095957
# 48 0 days 00:00:00.668150                  0.000636              0.062786
# 49 0 days 00:00:00.768179                  0.000531              0.058088
#
#     params_max_depth  params_max_iter     state
# 0                 68              584  COMPLETE
# 1                 24              352  COMPLETE
# 2                 18              379  COMPLETE
# 3                 28              231  COMPLETE
# 4                 25              662  COMPLETE
# 5                 26              877  COMPLETE
# 6                 75              427  COMPLETE
# 7                 86              410  COMPLETE
# 8                 63              850  COMPLETE
# 9                 19              207  COMPLETE
# 10                45              101  COMPLETE
# 11                51              912  COMPLETE
# 12                99              750  COMPLETE
# 13                41              739  COMPLETE
# 14                63              497  COMPLETE
# 15                10             1000  COMPLETE
# 16                59              315  COMPLETE
# 17                38              607  COMPLETE
# 18                38              552  COMPLETE
# 19                35              644  COMPLETE
# 20                52              480  COMPLETE
# 21                41              618  COMPLETE
# 22                32              695  COMPLETE
# 23                35              786  COMPLETE
# 24                10              632  COMPLETE
# 25                19              503  COMPLETE
# 26                47              283  COMPLETE
# 27                46              317  COMPLETE
# 28                52              210  COMPLETE
# 29                73              114  COMPLETE
# 30                45              330  COMPLETE
# 31                45              336  COMPLETE
# 32                29              264  COMPLETE
# 33                23              366  COMPLETE
# 34                58              162  COMPLETE
# 35                32              276  COMPLETE
# 36                48              567  COMPLETE
# 37                48              580  COMPLETE
# 38                56              448  COMPLETE
# 39                41              537  COMPLETE
# 40                66              399  COMPLETE
# 41                23              361  COMPLETE
# 42                38              439  COMPLETE
# 43                49              266  COMPLETE
# 44                15              680  COMPLETE
# 45                28              467  COMPLETE
# 46                42              166  COMPLETE
# 47                54              585  COMPLETE
# 48                87              515  COMPLETE
# 49                37              403  COMPLETE

# %%
study.best_trial.params
# Out:
# {'max_iter': 567,
#  'learning_rate': 0.06829862122784122,
#  'max_depth': 48,
#  'l2_regularization': 0.00048183914198247387}

# %%
optuna.visualization.plot_optimization_history(study)
#optuna.visualization.plot_param_importances(study) Learning_rate : 0.67, max_depth : 0.19
# Out:
# <div>                            <div id="c04e1739-64bf-4fbf-8434-6c33adf08263" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("c04e1739-64bf-4fbf-8434-6c33adf08263")) {                    Plotly.newPlot(                        "c04e1739-64bf-4fbf-8434-6c33adf08263",                        [{"cliponaxis":false,"hovertemplate":["l2_regularization (FloatDistribution): 0.05897169439525408<extra></extra>","max_iter (IntDistribution): 0.0819872490587475<extra></extra>","max_depth (IntDistribution): 0.1924457092151393<extra></extra>","learning_rate (FloatDistribution): 0.6665953473308591<extra></extra>"],"marker":{"color":"rgb(66,146,198)"},"orientation":"h","text":["0.06","0.08","0.19","0.67"],"textposition":"outside","x":[0.05897169439525408,0.0819872490587475,0.1924457092151393,0.6665953473308591],"y":["l2_regularization","max_iter","max_depth","learning_rate"],"type":"bar"}],                        {"showlegend":false,"title":{"text":"Hyperparameter Importances"},"xaxis":{"title":{"text":"Importance for Objective Value"}},"yaxis":{"title":{"text":"Hyperparameter"}},"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl ...

# %%
Hgbm_best = HistGradientBoostingClassifier(**study.best_trial.params,
                                           loss = "binary_crossentropy", 
                                            random_state=61)

# %%
Hgbm_best.fit(X_train, y_train)
# Out:
# C:\Users\user\anaconda3\Lib\site-packages\sklearn\utils\validation.py:767: FutureWarning:
#
# is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#
# C:\Users\user\anaconda3\Lib\site-packages\sklearn\utils\validation.py:605: FutureWarning:
#
# is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#
# C:\Users\user\anaconda3\Lib\site-packages\sklearn\utils\validation.py:614: FutureWarning:
#
# is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#
# C:\Users\user\anaconda3\Lib\site-packages\sklearn\utils\validation.py:605: FutureWarning:
#
# is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#
# C:\Users\user\anaconda3\Lib\site-packages\sklearn\utils\validation.py:614: FutureWarning:
#
# is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#
# C:\Users\user\anaconda3\Lib\site-packages\sklearn\ensemble\_hist_gradient_boosting\gradient_boosting.py:1998: FutureWarning:
#
# The loss 'binary_crossentropy' was deprecated in v1.1 and will be removed in version 1.3. Use 'log_loss' which is equivalent.
# HistGradientBoostingClassifier(l2_regularization=0.00048183914198247387,
#                                learning_rate=0.06829862122784122,
#                                loss='binary_crossentropy', max_depth=48,
#                                max_iter=567, random_state=61)

# %%
y_pred = Hgbm_best.predict(X_test)
accuracy = accuracy_score(y_test, y_pred)
print("정확도:", accuracy)
f1 = f1_score(y_test, y_pred, average='weighted')
print('f1 score :', f1)
# Out:
# 정확도: 0.8121161499533238
# f1 score : 0.7934972020522914
# C:\Users\user\anaconda3\Lib\site-packages\sklearn\utils\validation.py:767: FutureWarning:
#
# is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#
# C:\Users\user\anaconda3\Lib\site-packages\sklearn\utils\validation.py:605: FutureWarning:
#
# is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#
# C:\Users\user\anaconda3\Lib\site-packages\sklearn\utils\validation.py:614: FutureWarning:
#
# is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#
# C:\Users\user\anaconda3\Lib\site-packages\sklearn\utils\validation.py:605: FutureWarning:
#
# is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#
# C:\Users\user\anaconda3\Lib\site-packages\sklearn\utils\validation.py:614: FutureWarning:
#
# is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#
# C:\Users\user\anaconda3\Lib\site-packages\sklearn\utils\validation.py:605: FutureWarning:
#
# is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#
# C:\Users\user\anaconda3\Lib\site-packages\sklearn\utils\validation.py:614: FutureWarning:
#
# is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#
# C:\Users\user\anaconda3\Lib\site-packages\sklearn\utils\validation.py:605: FutureWarning:
#
# is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#
# C:\Users\user\anaconda3\Lib\site-packages\sklearn\utils\validation.py:614: FutureWarning:
#
# is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#
# C:\Users\user\anaconda3\Lib\site-packages\sklearn\utils\validation.py:605: FutureWarning:
#
# is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#
# C:\Users\user\anaconda3\Lib\site-packages\sklearn\utils\validation.py:614: FutureWarning:
#
# is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#
# C:\Users\user\anaconda3\Lib\site-packages\sklearn\utils\validation.py:605: FutureWarning:
#
# is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#
# C:\Users\user\anaconda3\Lib\site-packages\sklearn\utils\validation.py:614: FutureWarning:
#
# is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#
# C:\Users\user\anaconda3\Lib\site-packages\sklearn\utils\validation.py:605: FutureWarning:
#
# is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#
# C:\Users\user\anaconda3\Lib\site-packages\sklearn\utils\validation.py:614: FutureWarning:
#
# is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#
# C:\Users\user\anaconda3\Lib\site-packages\sklearn\utils\validation.py:605: FutureWarning:
#
# is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#
# C:\Users\user\anaconda3\Lib\site-packages\sklearn\utils\validation.py:614: FutureWarning:
#
# is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#
# C:\Users\user\anaconda3\Lib\site-packages\sklearn\utils\validation.py:605: FutureWarning:
#
# is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#
# C:\Users\user\anaconda3\Lib\site-packages\sklearn\utils\validation.py:614: FutureWarning:
#
# is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#
# C:\Users\user\anaconda3\Lib\site-packages\sklearn\utils\validation.py:605: FutureWarning:
#
# is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#
# C:\Users\user\anaconda3\Lib\site-packages\sklearn\utils\validation.py:614: FutureWarning:
#
# is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.

# %%
print(y.unique())
y_proba = Hgbm_best.predict_proba(test)
print(y_proba)
submission_df['defects'] = y_proba[:, 1]
submission_df.to_csv('submission.csv')
submission_df
# Out:
# [0 1]
# [[0.74856504 0.25143496]
#  [0.78496847 0.21503153]
#  [0.30934806 0.69065194]
#  ...
#  [0.79322788 0.20677212]
#  [0.90178524 0.09821476]
#  [0.20906786 0.79093214]]
# C:\Users\user\anaconda3\Lib\site-packages\sklearn\utils\validation.py:767: FutureWarning:
#
# is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#
# C:\Users\user\anaconda3\Lib\site-packages\sklearn\utils\validation.py:605: FutureWarning:
#
# is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#
# C:\Users\user\anaconda3\Lib\site-packages\sklearn\utils\validation.py:614: FutureWarning:
#
# is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#          defects
# id
# 101763  0.251435
# 101764  0.215032
# 101765  0.690652
# 101766  0.483614
# 101767  0.141881
# ...          ...
# 169600  0.274047
# 169601  0.104643
# 169602  0.206772
# 169603  0.098215
# 169604  0.790932
#
# [67842 rows x 1 columns]

# %%
정확도: 0.8116248218935783
Weighted F1 Score: 0.7930100686798354

# %%
정확도: 0.8111334938338328
Weighted F1 Score: 0.792443686558077

# %%
pd.read_csv('submission.csv', index_col='id')
# Out:
#          defects
# id
# 101763  0.251435
# 101764  0.215032
# 101765  0.690652
# 101766  0.483614
# 101767  0.141881
# ...          ...
# 169600  0.274047
# 169601  0.104643
# 169602  0.206772
# 169603  0.098215
# 169604  0.790932
#
# [67842 rows x 1 columns]

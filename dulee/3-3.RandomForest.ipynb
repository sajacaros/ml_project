# %%
# !pip install optuna
# Out:
# Collecting optuna
#   Downloading optuna-3.4.0-py3-none-any.whl (409 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 409.6/409.6 kB 9.6 MB/s eta 0:00:00
# Collecting alembic>=1.5.0 (from optuna)
#   Downloading alembic-1.12.0-py3-none-any.whl (226 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 226.0/226.0 kB 14.1 MB/s eta 0:00:00
# Collecting colorlog (from optuna)
#   Downloading colorlog-6.7.0-py2.py3-none-any.whl (11 kB)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from optuna) (1.23.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from optuna) (23.2)
# Requirement already satisfied: sqlalchemy>=1.3.0 in /usr/local/lib/python3.10/dist-packages (from optuna) (2.0.21)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from optuna) (4.66.1)
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.10/dist-packages (from optuna) (6.0.1)
# Collecting Mako (from alembic>=1.5.0->optuna)
#   Downloading Mako-1.2.4-py3-none-any.whl (78 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.7/78.7 kB 11.2 MB/s eta 0:00:00
# Requirement already satisfied: typing-extensions>=4 in /usr/local/lib/python3.10/dist-packages (from alembic>=1.5.0->optuna) (4.5.0)
# Requirement already satisfied: greenlet!=0.4.17 in /usr/local/lib/python3.10/dist-packages (from sqlalchemy>=1.3.0->optuna) (3.0.0)
# Requirement already satisfied: MarkupSafe>=0.9.2 in /usr/local/lib/python3.10/dist-packages (from Mako->alembic>=1.5.0->optuna) (2.1.3)
# Installing collected packages: Mako, colorlog, alembic, optuna
# Successfully installed Mako-1.2.4 alembic-1.12.0 colorlog-6.7.0 optuna-3.4.0

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.model_selection import StratifiedKFold, train_test_split
from sklearn.metrics import roc_auc_score, f1_score
from sklearn.ensemble import RandomForestClassifier, ExtraTreesClassifier

import optuna, pickle

# %% [markdown]
# # 데이터 로드

# %%
import os

colab = os.path.isdir('./sample_data')
mount = os.path.isdir('/content/drive')
if colab:
    if not mount:
        from google.colab import drive
        drive.mount('/content/drive')
    base_path = '/content/drive/MyDrive/Colab Notebooks/5_ML_Project/dulee/'
    data_path = '/content/drive/MyDrive/Colab Notebooks/5_ML_Project/data/'
else:
    base_path = ''
    data_path = '../data/'
# Out:
# Mounted at /content/drive

# %%
submission_df = pd.read_csv(data_path+'sample_submission.csv', index_col='id')

train = pd.read_csv(base_path + 'train.csv', index_col='id')
test = pd.read_csv(base_path + 'test.csv', index_col='id')

# %% [markdown]
# ##### 변수 설정

# %%
X = train.drop(columns=['defects'])
y = train['defects']
X_test = test

K = 15

# %% [markdown]
# # 모델 학습

# %% [markdown]
# ### RandomForest

# %% [markdown]
# ##### 기본 모델

# %%
# X_train, X_val, y_train, y_val = train_test_split(X, y, random_state=61, shuffle=True, stratify=y)
# model = RandomForestClassifier(random_state=61)
# model.fit(X_train, y_train)

# %%
# y_proba_randomforest_basic = model.predict_proba(X_val)[:, 1]
# roc_auc_score(y_val, y_proba_randomforest_basic)

# %% [markdown]
# ##### hyper-parameter tuning

# %%
import os
os.cpu_count()
# Out:
# 8

# %%
def optimizer(trial):

    # n_estimators = trial.suggest_categorical('n_estimators', [200, 300, 400, 500, 600, 700])
    min_samples_leaf = trial.suggest_int('min_samples_leaf', 1, 200)
    # max_depth = trial.suggest_int('max_depth', 11, 20)
    max_features = trial.suggest_float('max_features', 0.5, 0.8)
    # min_samples_split = trial.suggest_int('min_samples_split', 2, 50)
    # min_impurity_decrease = trial.suggest_float('min_impurity_decrease', 0.0001, 0.001)

    model = RandomForestClassifier(
        n_estimators=100,
        min_samples_leaf=min_samples_leaf,
        max_depth=9,
        max_features=max_features,
        # min_samples_split=min_samples_split,
        # min_impurity_decrease=min_impurity_decrease,
        random_state=61,
        # n_jobs=-1,
        n_jobs=os.cpu_count()-1,
    )

    folds = StratifiedKFold(n_splits = K) # RandomForest는 shuffle이 필요 없음.
    scores = []
    for train_idx, val_idx in folds.split(X, y):
        model.fit(X.iloc[train_idx], y.iloc[train_idx])

        y_true = y.iloc[val_idx]
        y_proba = model.predict_proba(X.iloc[val_idx])[:, 1]
        scores.append(roc_auc_score(y_true, y_proba))
    return np.mean(scores)

# %%
study = optuna.create_study(direction="maximize")
study.optimize(optimizer, n_trials=100)
# Out:
# [I 2023-10-17 13:38:04,798] A new study created in memory with name: no-name-dafd4efd-c5b3-459e-ac81-44730726dfdb
# [I 2023-10-17 13:41:26,138] Trial 0 finished with value: 0.8989424871554429 and parameters: {'min_samples_leaf': 108, 'max_features': 0.6887567981095749}. Best is trial 0 with value: 0.8989424871554429.
# [I 2023-10-17 13:44:58,039] Trial 1 finished with value: 0.8961650330523615 and parameters: {'min_samples_leaf': 163, 'max_features': 0.7264604814503048}. Best is trial 0 with value: 0.8989424871554429.
# [I 2023-10-17 13:48:05,922] Trial 2 finished with value: 0.8940698623444255 and parameters: {'min_samples_leaf': 181, 'max_features': 0.6610019816497058}. Best is trial 0 with value: 0.8989424871554429.
# [I 2023-10-17 13:51:43,218] Trial 3 finished with value: 0.9020302918926452 and parameters: {'min_samples_leaf': 62, 'max_features': 0.7543624946406768}. Best is trial 3 with value: 0.9020302918926452.
# [I 2023-10-17 13:55:30,461] Trial 4 finished with value: 0.8997765113235225 and parameters: {'min_samples_leaf': 101, 'max_features': 0.7941012086152697}. Best is trial 3 with value: 0.9020302918926452.
# [I 2023-10-17 13:59:17,360] Trial 5 finished with value: 0.8981946868911541 and parameters: {'min_samples_leaf': 133, 'max_features': 0.799780569839193}. Best is trial 3 with value: 0.9020302918926452.
# [I 2023-10-17 14:02:27,565] Trial 6 finished with value: 0.8979932700833315 and parameters: {'min_samples_leaf': 120, 'max_features': 0.639976998813083}. Best is trial 3 with value: 0.9020302918926452.
# [I 2023-10-17 14:05:37,911] Trial 7 finished with value: 0.8989313704024621 and parameters: {'min_samples_leaf': 99, 'max_features': 0.6540322121085225}. Best is trial 3 with value: 0.9020302918926452.
# [I 2023-10-17 14:08:29,005] Trial 8 finished with value: 0.896665628770789 and parameters: {'min_samples_leaf': 142, 'max_features': 0.5957725276569045}. Best is trial 3 with value: 0.9020302918926452.
# [I 2023-10-17 14:11:29,542] Trial 9 finished with value: 0.9033893292287645 and parameters: {'min_samples_leaf': 14, 'max_features': 0.5975481670901955}. Best is trial 9 with value: 0.9033893292287645.
# [I 2023-10-17 14:14:00,742] Trial 10 finished with value: 0.9020423632473092 and parameters: {'min_samples_leaf': 4, 'max_features': 0.5137639571043165}. Best is trial 9 with value: 0.9033893292287645.
# [I 2023-10-17 14:16:33,283] Trial 11 finished with value: 0.902121210684553 and parameters: {'min_samples_leaf': 2, 'max_features': 0.5041563981110764}. Best is trial 9 with value: 0.9033893292287645.
# [I 2023-10-17 14:19:06,954] Trial 12 finished with value: 0.90216622544515 and parameters: {'min_samples_leaf': 3, 'max_features': 0.5167468275940788}. Best is trial 9 with value: 0.9033893292287645.
# [I 2023-10-17 14:21:53,178] Trial 13 finished with value: 0.9010968895150627 and parameters: {'min_samples_leaf': 46, 'max_features': 0.5641397327506239}. Best is trial 9 with value: 0.9033893292287645.
# [I 2023-10-17 14:24:37,218] Trial 14 finished with value: 0.901607604426953 and parameters: {'min_samples_leaf': 39, 'max_features': 0.5549039858478659}. Best is trial 9 with value: 0.9033893292287645.
# [I 2023-10-17 14:27:36,300] Trial 15 finished with value: 0.9034715618995244 and parameters: {'min_samples_leaf': 21, 'max_features': 0.5957813531708926}. Best is trial 15 with value: 0.9034715618995244.
# [I 2023-10-17 14:30:33,794] Trial 16 finished with value: 0.902501996584809 and parameters: {'min_samples_leaf': 34, 'max_features': 0.607305720174176}. Best is trial 15 with value: 0.9034715618995244.
# [I 2023-10-17 14:33:28,636] Trial 17 finished with value: 0.9003184827370203 and parameters: {'min_samples_leaf': 72, 'max_features': 0.6117805257306713}. Best is trial 15 with value: 0.9034715618995244.
# [I 2023-10-17 14:36:23,005] Trial 18 finished with value: 0.9029366955512157 and parameters: {'min_samples_leaf': 23, 'max_features': 0.5738200914915387}. Best is trial 15 with value: 0.9034715618995244.
# [I 2023-10-17 14:39:04,672] Trial 19 finished with value: 0.8991729164320909 and parameters: {'min_samples_leaf': 78, 'max_features': 0.5531887508900675}. Best is trial 15 with value: 0.9034715618995244.
# [I 2023-10-17 14:42:12,335] Trial 20 finished with value: 0.9036473615148957 and parameters: {'min_samples_leaf': 23, 'max_features': 0.625637433135477}. Best is trial 20 with value: 0.9036473615148957.
# [I 2023-10-17 14:45:23,280] Trial 21 finished with value: 0.903683217852199 and parameters: {'min_samples_leaf': 19, 'max_features': 0.6241438994038004}. Best is trial 21 with value: 0.903683217852199.
# [I 2023-10-17 14:48:32,240] Trial 22 finished with value: 0.9016286555784786 and parameters: {'min_samples_leaf': 54, 'max_features': 0.6329358744495589}. Best is trial 21 with value: 0.903683217852199.
# [I 2023-10-17 14:51:52,527] Trial 23 finished with value: 0.9036556081083184 and parameters: {'min_samples_leaf': 26, 'max_features': 0.6758027270925606}. Best is trial 21 with value: 0.903683217852199.
# [I 2023-10-17 14:54:59,281] Trial 24 finished with value: 0.9032896287709998 and parameters: {'min_samples_leaf': 29, 'max_features': 0.6661594780339102}. Best is trial 21 with value: 0.903683217852199.
# [I 2023-10-17 14:58:15,387] Trial 25 finished with value: 0.9002450530731337 and parameters: {'min_samples_leaf': 84, 'max_features': 0.689385144684482}. Best is trial 21 with value: 0.903683217852199.
# [I 2023-10-17 15:01:20,866] Trial 26 finished with value: 0.9016286555784786 and parameters: {'min_samples_leaf': 54, 'max_features': 0.6294338882954016}. Best is trial 21 with value: 0.903683217852199.
# [I 2023-10-17 15:04:39,544] Trial 27 finished with value: 0.9032832693913908 and parameters: {'min_samples_leaf': 35, 'max_features': 0.6747910716914371}. Best is trial 21 with value: 0.903683217852199.
# [I 2023-10-17 15:07:44,151] Trial 28 finished with value: 0.9038775284810102 and parameters: {'min_samples_leaf': 14, 'max_features': 0.6268108274463439}. Best is trial 28 with value: 0.9038775284810102.
# [I 2023-10-17 15:10:54,256] Trial 29 finished with value: 0.8942125883795956 and parameters: {'min_samples_leaf': 198, 'max_features': 0.6910966114160159}. Best is trial 28 with value: 0.9038775284810102.
# [I 2023-10-17 15:13:58,913] Trial 30 finished with value: 0.9008955388910015 and parameters: {'min_samples_leaf': 68, 'max_features': 0.6423497625583057}. Best is trial 28 with value: 0.9038775284810102.
# [I 2023-10-17 15:16:53,004] Trial 31 finished with value: 0.9032836447499732 and parameters: {'min_samples_leaf': 16, 'max_features': 0.6170251304585055}. Best is trial 28 with value: 0.9038775284810102.
# [I 2023-10-17 15:20:01,037] Trial 32 finished with value: 0.9026921998461045 and parameters: {'min_samples_leaf': 42, 'max_features': 0.6248951927561943}. Best is trial 28 with value: 0.9038775284810102.
# [I 2023-10-17 15:23:12,056] Trial 33 finished with value: 0.9038775284810102 and parameters: {'min_samples_leaf': 14, 'max_features': 0.6577627073789578}. Best is trial 28 with value: 0.9038775284810102.
# [I 2023-10-17 15:26:22,299] Trial 34 finished with value: 0.9038681480919439 and parameters: {'min_samples_leaf': 11, 'max_features': 0.6509037568739559}. Best is trial 28 with value: 0.9038775284810102.
# [I 2023-10-17 15:29:32,872] Trial 35 finished with value: 0.9041471491841169 and parameters: {'min_samples_leaf': 9, 'max_features': 0.6544484650435337}. Best is trial 35 with value: 0.9041471491841169.
# [I 2023-10-17 15:32:58,233] Trial 36 finished with value: 0.9045384274378553 and parameters: {'min_samples_leaf': 10, 'max_features': 0.7078787203735197}. Best is trial 36 with value: 0.9045384274378553.
# [I 2023-10-17 15:36:21,238] Trial 37 finished with value: 0.902206458836051 and parameters: {'min_samples_leaf': 50, 'max_features': 0.7124969344517249}. Best is trial 36 with value: 0.9045384274378553.

# %%
print("Best roc_auc_score: %.5f" % study.best_value)
print("Best params: ", study.best_trial.params)
print(study.trials_dataframe()['duration'].sum())

# %% [markdown]
# ##### best model

# %%
# model_best = RandomForestClassifier(
#     min_samples_leaf=78,
#     max_depth=9,
#     max_features=0.6222106369274514,
#     # min_samples_split=min_samples_split,
#     # min_impurity_decrease=min_impurity_decrease,
#     random_state=61,
#     # n_jobs=-1,
#     n_jobs=os.cpu_count()-1,)

# %%
def oof_predict(best_model):
    folds = StratifiedKFold(n_splits = K, random_state=61, shuffle=True)
    predicted_probas = []

    for train_idx, val_idx in folds.split(X, y):
        best_model.fit(X.iloc[train_idx], y.iloc[train_idx])
        predicted_probas.append(best_model.predict_proba(X_test)[:, 1])
    return np.mean(predicted_probas, axis=0)

# %%
model_best = RandomForestClassifier(**study.best_trial.params,
                                    random_state=61, n_jobs=-1)
model_best.fit(X, y)
y_proba = model_best.predict_proba(X_test)[:, 1]
y_proba_oof = oof_predict(model_best)

# %%
# save model
pickle.dump(model_best, open(base_path + "rf_best.pickle", "wb"))

# %% [markdown]
# ##### 분석

# %%
# optuna가 시도했던 모든 실험 관련 데이터
param_analysis = study.trials_dataframe().sort_values(by=['value'], ascending=False)
param_analysis.to_csv(base_path + 'RF_param_analysis.csv')

fig, axes = plt.subplots(2, 3, figsize=(12, 8))
for col, ax in zip(param_analysis.columns[5:-1], axes.ravel()):
    sns.scatterplot(param_analysis, x='value', y=col, ax=ax)
plt.show()
fig.savefig(base_path + 'RF_param_analysis.png')

# %%
# 실험 기록 시각화
optuna.visualization.plot_optimization_history(study)

# %%
# hyper-parameter들의 중요도
optuna.visualization.plot_param_importances(study)

# %% [markdown]
# # 제출

# %%
submission_df['defects'] = y_proba
submission_df.to_csv(base_path + 'submission_RandomForest.csv')
submission_df['defects'] = y_proba_oof
submission_df.to_csv(base_path + 'submission_RandomForest_oof.csv')
submission_df
